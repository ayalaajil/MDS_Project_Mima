# %%
import pandas as pd
import numpy as np
import random
from autocorrect import Speller
import re
from LLM import LLM
from PromptBuilder import PromptBuilder
from metadata import language_registers, discussion_tones

# %% [markdown]
# ### Biollama :

# %%
model = LLM("iRASC/BioLlama-Ko-8B")
# Out:
# /home/laajila/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:862: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /home/laajila/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# Device set to use cuda:0
# Model loaded on device(s): {'': 0}

# %% [markdown]
# ### PRO dataset :

# %%
a = pd.read_excel('PRO-CTCAE_Questionnaire_Terminology.xls', sheet_name = 'PRO')
a.head(4)
# Out:
#   NCIt Code of Subset                               Subset Name  \
# 0             C205862  PRO-CTCAE Oral Adverse Event Terminology
# 1             C205862  PRO-CTCAE Oral Adverse Event Terminology
# 2             C205862  PRO-CTCAE Oral Adverse Event Terminology
# 3             C205862  PRO-CTCAE Oral Adverse Event Terminology
#
#   NCIt Concept Code                                            NCIt PT  \
# 0           C205929  Cracking at the Corners of the Mouth (Cheilosi...
# 1           C205927                   Difficulty Swallowing, PRO-CTCAE
# 2           C205926                               Dry Mouth, PRO-CTCAE
# 3           C205931                              Hoarseness, PRO-CTCAE
#
#                                      NCIt Definition  \
# 0  Cheilosis or cheilitis as recorded on the PRO-...
# 1  Problems with swallowing as recorded on the PR...
# 2  Dryness of the oral mucosa secondary to a decr...
# 3  A raspy alteration in one's voice as recorded ...
#
#                                         PRO-CTCAE PT  \
# 0  Cracking at the corners of the mouth (cheilosi...
# 1                              Difficulty Swallowing
# 2                                          Dry Mouth
# 3                                         Hoarseness
#
#   Has PRO-CTCAE Attribute Code Has PRO-CTCAE Attribute PT  \
# 0                       C25676                   Severity
# 1                       C25676                   Severity
# 2                       C25676                   Severity
# 3                       C25676                   Severity
#
#   PRO-CTCAE Attribute Has Value Code PRO-CTCAE Value PT
# 0                                NaN                NaN
# 1                                NaN                NaN
# 2                                NaN                NaN
# 3                                NaN                NaN

# %%
index = (a [a['PRO-CTCAE PT'] == 'Pain and swelling at injection site']).index.values[0] +1 
symptoms = a.iloc[:index]['PRO-CTCAE PT'].values
symptoms
# Out:
# array(['Cracking at the corners of the mouth (cheilosis/cheilitis)',
#        'Difficulty Swallowing', 'Dry Mouth', 'Hoarseness',
#        'Mouth/throat sores', 'Voice quality changes', 'Abdominal pain',
#        'Bloating', 'Constipation', 'Decreased appetite', 'Diarrhea',
#        'Fecal incontinence', 'Gas', 'Heartburn', 'Hiccups', 'Nausea',
#        'Taste Changes', 'Vomiting', 'Coughing', 'Shortness of breath',
#        'Wheezing', 'Heart palpitations', 'Swelling (arms or legs)',
#        'Acne', 'Bed/pressure sores', 'Hair loss',
#        'Hand-foot syndrome (a rash of the hands and feet that can cause cracking, peeling, redness or pain)',
#        'Hives', 'Itching', 'Nail discoloration', 'Nail loss',
#        'Nail ridging', 'Radiation skin reaction', 'Rash',
#        'Sensitivity to sunlight', 'Skin darkening', 'Skin dryness',
#        'Stretch marks', 'Dizziness', 'Numbness & tingling',
#        'Blurred vision', 'Flashing lights', 'Ringing in ears',
#        'Visual floaters', 'Watery eyes', 'Concentration', 'Memory',
#        'General pain', 'Headache', 'Joint pain', 'Muscle pain', 'Fatigue',
#        'Insomnia', 'Anxious', 'Discouraged', 'Sad',
#        'Change in usual urine color',
#        'Irregular periods/vaginal bleeding',
#        'Missed expected menstrual period', 'Painful urination',
#        'Urinary frequency', 'Urinary incontinence', 'Urinary urgency',
#        'Vaginal discharge', 'Vaginal dryness', 'Decreased libido',
#        'Delayed orgasm', 'Achieve and maintain erection', 'Ejaculation',
#        'Pain with sexual intercourse', 'Unable to have orgasm',
#        'Body odor', 'Breast swelling and tenderness', 'Bruising',
#        'Chills', 'Decreased sweating', 'Hot flashes',
#        'Increased sweating', 'Nosebleed', 'Other Symptoms',
#        'Pain and swelling at injection site'], dtype=object)

# %%
Dict = {}

for symptom in symptoms : 

    try:
        Dict[symptom] = {}
        descriptions_code = a[a['PRO-CTCAE PT'] == symptom]['Has PRO-CTCAE Attribute Code'].values[0].split(" || ")
        descriptions = a [a['PRO-CTCAE PT'] == symptom]['Has PRO-CTCAE Attribute PT'].values[0].split(" || ")
        for description in descriptions :
            Dict[symptom][description]  = a[a['PRO-CTCAE PT'] == description  ]['PRO-CTCAE Value PT'].values[0].split(" || ")
    
    except Exception as e :
        print(e)
# Out:
# 'float' object has no attribute 'split'

# %%
Dict
# Out:
# {'Cracking at the corners of the mouth (cheilosis/cheilitis)': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Difficulty Swallowing': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Dry Mouth': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Hoarseness': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Mouth/throat sores': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Voice quality changes': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Abdominal pain': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Bloating': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Constipation': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Decreased appetite': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Diarrhea': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely']},
#  'Fecal incontinence': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely']},
#  'Gas': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Heartburn': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Hiccups': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Nausea': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Taste Changes': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Vomiting': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Coughing': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Shortness of breath': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Wheezing': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Heart palpitations': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Swelling (arms or legs)': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Acne': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Bed/pressure sores': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Hair loss': {'Amount': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much']},
#  'Hand-foot syndrome (a rash of the hands and feet that can cause cracking, peeling, redness or pain)': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Hives': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Itching': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Nail discoloration': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Nail loss': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Nail ridging': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Radiation skin reaction': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Rash': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Sensitivity to sunlight': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Skin darkening': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Skin dryness': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Stretch marks': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Dizziness': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Numbness & tingling': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Blurred vision': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Flashing lights': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Ringing in ears': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Visual floaters': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Watery eyes': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Concentration': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Memory': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'General pain': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Headache': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Joint pain': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Muscle pain': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Fatigue': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Insomnia': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Anxious': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Discouraged': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Sad': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Change in usual urine color': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Irregular periods/vaginal bleeding': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Missed expected menstrual period': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Painful urination': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Urinary frequency': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely']},
#  'Urinary incontinence': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely']},
#  'Urinary urgency': {'Interference (with daily activities)': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much'],
#   'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely']},
#  'Vaginal discharge': {'Amount': ['Not at all',
#    'A little bit',
#    'Somewhat',
#    'Quite a bit',
#    'Very much']},
#  'Vaginal dryness': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Decreased libido': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Delayed orgasm': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Achieve and maintain erection': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Ejaculation': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely']},
#  'Pain with sexual intercourse': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Unable to have orgasm': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Body odor': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Breast swelling and tenderness': {'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Bruising': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Chills': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Decreased sweating': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']},
#  'Hot flashes': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Increased sweating': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Nosebleed': {'Frequency': ['Almost constantly',
#    'Not sexually active',
#    'Prefer not to answer',
#    'Occasionally',
#    'Frequently',
#    'Never',
#    'Rarely'],
#   'Severity': ['Very severe',
#    'Not sexually active',
#    'Prefer not to answer',
#    'None',
#    'Not applicable',
#    'Moderate',
#    'Mild',
#    'Severe']},
#  'Other Symptoms': {},
#  'Pain and swelling at injection site': {'Presence/Absence': ['Not sexually active',
#    'Prefer not to answer',
#    'Not applicable',
#    'No',
#    'Yes']}}

# %%
reversed_dict = dict(reversed(list(Dict.items())))
print(reversed_dict)
# Out:
# {'Pain and swelling at injection site': {'Presence/Absence': ['Not sexually active', 'Prefer not to answer', 'Not applicable', 'No', 'Yes']}, 'Other Symptoms': {}, 'Nosebleed': {'Frequency': ['Almost constantly', 'Not sexually active', 'Prefer not to answer', 'Occasionally', 'Frequently', 'Never', 'Rarely'], 'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Increased sweating': {'Frequency': ['Almost constantly', 'Not sexually active', 'Prefer not to answer', 'Occasionally', 'Frequently', 'Never', 'Rarely'], 'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Hot flashes': {'Frequency': ['Almost constantly', 'Not sexually active', 'Prefer not to answer', 'Occasionally', 'Frequently', 'Never', 'Rarely'], 'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Decreased sweating': {'Presence/Absence': ['Not sexually active', 'Prefer not to answer', 'Not applicable', 'No', 'Yes']}, 'Chills': {'Frequency': ['Almost constantly', 'Not sexually active', 'Prefer not to answer', 'Occasionally', 'Frequently', 'Never', 'Rarely'], 'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Bruising': {'Presence/Absence': ['Not sexually active', 'Prefer not to answer', 'Not applicable', 'No', 'Yes']}, 'Breast swelling and tenderness': {'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Body odor': {'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Unable to have orgasm': {'Presence/Absence': ['Not sexually active', 'Prefer not to answer', 'Not applicable', 'No', 'Yes']}, 'Pain with sexual intercourse': {'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Ejaculation': {'Frequency': ['Almost constantly', 'Not sexually active', 'Prefer not to answer', 'Occasionally', 'Frequently', 'Never', 'Rarely']}, 'Achieve and maintain erection': {'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Delayed orgasm': {'Presence/Absence': ['Not sexually active', 'Prefer not to answer', 'Not applicable', 'No', 'Yes']}, 'Decreased libido': {'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Vaginal dryness': {'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Vaginal discharge': {'Amount': ['Not at all', 'A little bit', 'Somewhat', 'Quite a bit', 'Very much']}, 'Urinary urgency': {'Interference (with daily activities)': ['Not at all', 'A little bit', 'Somewhat', 'Quite a bit', 'Very much'], 'Frequency': ['Almost constantly', 'Not sexually active', 'Prefer not to answer', 'Occasionally', 'Frequently', 'Never', 'Rarely']}, 'Urinary incontinence': {'Interference (with daily activities)': ['Not at all', 'A little bit', 'Somewhat', 'Quite a bit', 'Very much'], 'Frequency': ['Almost constantly', 'Not sexually active', 'Prefer not to answer', 'Occasionally', 'Frequently', 'Never', 'Rarely']}, 'Urinary frequency': {'Interference (with daily activities)': ['Not at all', 'A little bit', 'Somewhat', 'Quite a bit', 'Very much'], 'Frequency': ['Almost constantly', 'Not sexually active', 'Prefer not to answer', 'Occasionally', 'Frequently', 'Never', 'Rarely']}, 'Painful urination': {'Severity': ['Very severe', 'Not sexually active', 'Prefer not to answer', 'None', 'Not applicable', 'Moderate', 'Mild', 'Severe']}, 'Missed expected menstrual period': {'Presence/Absence': ['No ...

# %%
import itertools

prompt_builder = PromptBuilder()

data = []
c = 0
for symptom, descriptions in reversed_dict.items():

    # Generate all (description, meta) combinations
    description_meta_combinations = list(itertools.product(descriptions.keys(), *descriptions.values()))

    for description, *meta_combinations in description_meta_combinations:

        for meta_set in meta_combinations:

            if c % 100 == 0:
                print(f"Generated {c+100} sentences...")
        
            detail_level = np.random.choice([1, 2, 3, 4, 5])
                        
            enumeration = np.random.choice([True, False], p=[0.2, 0.8])

            explicit_symptom = np.random.choice([True, False], p=[0.2, 0.8])


            language_style = random.choice(language_registers)['name']
            tone = random.choice(discussion_tones)['name']
            spelling_errors = random.choice([True, False])

            prompt = prompt_builder.build_prompt(
                symptoms=[symptom],
                description=description,
                meta=meta_set,
                detail_level=detail_level,
                enumeration=enumeration,
                explicit_symptom=explicit_symptom,
                language_style=language_style,
                spelling_errors=spelling_errors,
                tone=tone
            )
            
            phrase_generated = model.generate_text(messages=prompt)

            data.append([
                phrase_generated, symptom, description, meta_set, language_style, 
                tone, detail_level, enumeration, explicit_symptom, spelling_errors
            ])
            c += 1

df = pd.DataFrame(data, columns=[
    "Dialogue_Generated", "Symptom", "Description", "Meta", 
    "Language_Style", "Tone", "Detail_Level", "Enumeration", 
    "Explicit_Symptom", "Spelling_Errors"
])
# Out:
# Generated 100 sentences...
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Generated 200 sentences...
# Generated 300 sentences...
# Generated 400 sentences...
# Generated 500 sentences...
# Generated 600 sentences...
# Generated 700 sentences...
# Generated 800 sentences...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 42
#      28 spelling_errors = random.choice([True, False])
#      30 prompt = prompt_builder.build_prompt(
#      31     symptoms=[symptom],
#      32     description=description,
#    (...)
#      39     tone=tone
#      40 )
# ---> 42 phrase_generated = model.generate_text(messages=prompt)
#      44 data.append([
#      45     phrase_generated, symptom, description, meta_set, language_style,
#      46     tone, detail_level, enumeration, explicit_symptom, spelling_errors
#      47 ])
#      48 c += 1
#
# File ~/mima_newcode/clean_code/LLM.py:73, in LLM.generate_text(self, messages)
#      63 def generate_text(self, messages: list) -> str:
#      64     """
#      65     Generate text based on a list of messages (conversational format).
#      66
#    (...)
#      70     :return: (str) Generated text response from the model.
#      71     """
# ---> 73     outputs = self.text_generator(messages)
#      75     # Extract the generated text
#      76     generated_text = outputs[0]["generated_text"]
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/pipelines/text_generation.py:280, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     277 if isinstance(first_item, (list, tuple, dict)):
#     278     # We have one or more prompts in list-of-dicts format, so this is chat mode
#     279     if isinstance(first_item, dict):
# --> 280         return super().__call__(Chat(text_inputs), **kwargs)
#     281     else:
#     282         chats = (Chat(chat) for chat in text_inputs)  # 🐈 🐈 🐈
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/pipelines/base.py:1371, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1363     return next(
#    1364         iter(
#    1365             self.get_iterator(
#    (...)
#    1368         )
#    1369     )
#    1370 else:
# -> 1371     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/pipelines/base.py:1378, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1376 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1377     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1378     model_outputs = self.forward(model_inputs, **forward_params)
#    1379     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1380     return outputs
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/pipelines/base.py:1278, in Pipeline.forward(self, model_inputs, **forward_params)
#    1276     with inference_context():
#    1277         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1278         model_outputs = self._forward(model_inputs, **forward_params)
#    1279         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1280 else:
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/pipelines/text_generation.py:385, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     382 if "generation_config" not in generate_kwargs:
#     383     generate_kwargs["generation_config"] = self.generation_config
# --> 385 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     387 if isinstance(output, ModelOutput):
#     388     generated_sequence = output.sequences
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/generation/utils.py:2326, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2318     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2319         input_ids=input_ids,
#    2320         expand_size=generation_config.num_return_sequences,
#    2321         is_encoder_decoder=self.config.is_encoder_decoder,
#    2322         **model_kwargs,
#    2323     )
#    2325     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2326     result = self._sample(
#    2327         input_ids,
#    2328         logits_processor=prepared_logits_processor,
#    2329         stopping_criteria=prepared_stopping_criteria,
#    2330         generation_config=generation_config,
#    2331         synced_gpus=synced_gpus,
#    2332         streamer=streamer,
#    2333         **model_kwargs,
#    2334     )
#    2336 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2337     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2338     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2339         input_ids=input_ids,
#    2340         expand_size=generation_config.num_beams,
#    2341         is_encoder_decoder=self.config.is_encoder_decoder,
#    2342         **model_kwargs,
#    2343     )
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/generation/utils.py:3289, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3287     is_prefill = False
#    3288 else:
# -> 3289     outputs = model_forward(**model_inputs, return_dict=True)
#    3291 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3292 model_kwargs = self._update_model_kwargs_for_generation(
#    3293     outputs,
#    3294     model_kwargs,
#    3295     is_encoder_decoder=self.config.is_encoder_decoder,
#    3296 )
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:853, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, logits_to_keep, **kwargs)
#     850 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     852 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 853 outputs = self.model(
#     854     input_ids=input_ids,
#     855     attention_mask=attention_mask,
#     856     position_ids=position_ids,
#     857     past_key_values=past_key_values,
#     858     inputs_embeds=inputs_embeds,
#     859     use_cache=use_cache,
#     860     output_attentions=output_attentions,
#     861     output_hidden_states=output_hidden_states,
#     862     return_dict=return_dict,
#     863     cache_position=cache_position,
#     864     **kwargs,
#     865 )
#     867 hidden_states = outputs[0]
#     868 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:601, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     589     layer_outputs = self._gradient_checkpointing_func(
#     590         decoder_layer.__call__,
#     591         hidden_states,
#    (...)
#     598         position_embeddings,
#     599     )
#     600 else:
# --> 601     layer_outputs = decoder_layer(
#     602         hidden_states,
#     603         attention_mask=causal_mask,
#     604         position_ids=position_ids,
#     605         past_key_value=past_key_values,
#     606         output_attentions=output_attentions,
#     607         use_cache=use_cache,
#     608         cache_position=cache_position,
#     609         position_embeddings=position_embeddings,
#     610         **flash_attn_kwargs,
#     611     )
#     613 hidden_states = layer_outputs[0]
#     615 if output_attentions:
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:358, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     356 # Fully Connected
#     357 residual = hidden_states
# --> 358 hidden_states = self.post_attention_layernorm(hidden_states)
#     359 hidden_states = self.mlp(hidden_states)
#     360 hidden_states = residual + hidden_states
#
# File ~/miniconda3/envs/darts_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1918, in Module.__getattr__(self, name)
#    1909         self._backward_pre_hooks = OrderedDict()
#    1911 # On the return type:
#    1912 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1913 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1916 # See full discussion on the problems with returning `Union` here
#    1917 # https://github.com/microsoft/pyright/issues/4213
# -> 1918 def __getattr__(self, name: str) -> Any:
#    1919     if "_parameters" in self.__dict__:
#    1920         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(data, columns=["Dialogue_Generated", "symptom", "description", "meta", "language_style", "Tone", "Detail_level", "Enumeration", "Explicit_symptom", "Spelling_errors"])

# %%
df['Dialogue_Generated'].iloc[12]
# Out:
# ' "I have been experiencing frequent and severe nosebleeds for the past month."'

# %%
df['Dialogue_Generated'].iloc[100]
# Out:
# ' "My nose bleeds so severely that I am left with a puddle of blood on the floor, and I am left feeling enraged and helpless."'

# %%
df.shape
# Out:
# (738, 10)

# %%
df.to_csv('New_generated_dataset_with_biollama8B_700.csv')
